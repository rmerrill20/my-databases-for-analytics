# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world")

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world")

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg://postgres:A09a11S28!@localhost:5432/World")

# %%
with engine.connect() as connection:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
query = """
SELECT
    c.name AS country_name,
    COUNT(cl.language) AS official_language_count
FROM country AS c
JOIN countrylanguage AS cl
    ON c.code = cl.countrycode
WHERE cl.isofficial = 'T'
GROUP BY c.code, c.name
HAVING COUNT(cl.language) > 2
ORDER BY official_language_count DESC;
"""

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg://postgres:A09a11S28!@localhost:5432/World")

# %%
query = """
SELECT c.name AS country,
       COUNT(cl.language) AS official_languages
FROM country AS c
JOIN countrylanguage AS cl
    ON c.code = cl.countrycode
WHERE cl.isofficial = 'T'
GROUP BY c.name
HAVING COUNT(cl.language) > 2
ORDER BY official_languages DESC;
"""

df = pd.read_sql(query, engine)
df
# Out:
#                                              country  official_languages
# 0  Switzerland                                   ...                   4
# 1  South Africa                                  ...                   4
# 2  Vanuatu                                       ...                   3
# 3  Belgium                                       ...                   3
# 4  Luxembourg                                    ...                   3
# 5  Peru                                          ...                   3
# 6  Bolivia                                       ...                   3
# 7  Singapore                                     ...                   3

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:A09a11S28!@localhost:5432/World")

# %%
chart_query = """
SELECT TRIM(c.name) AS name,
       COUNT(cl.language) AS num_languages
FROM country AS c
JOIN countrylanguage AS cl
  ON c.code = cl.countrycode
WHERE cl.isofficial = 'T'
GROUP BY TRIM(c.name)
HAVING COUNT(cl.language) > 2
ORDER BY num_languages DESC;
"""

chart_df = pd.read_sql(chart_query, engine)

chart_df.plot(kind="bar", x="name", y="num_languages", figsize=(12, 6), legend=False)

plt.xlabel("Country")
plt.ylabel("Number of Official Languages")
plt.title("Countries with More Than Two Official Languages")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://postgres:A09a11S28!@localhost:5432/World")

# %%
chart_query = """
SELECT TRIM(c.name) AS name,
       COUNT(cl.language) AS num_languages
FROM country AS c
JOIN countrylanguage AS cl
  ON c.code = cl.countrycode
WHERE cl.isofficial = 'T'
GROUP BY TRIM(c.name)
HAVING COUNT(cl.language) = 4
ORDER BY num_languages DESC;
"""

chart_df = pd.read_sql(chart_query, engine)

chart_df.plot(kind="bar", x="name", y="num_languages", figsize=(12, 6), legend=False)

plt.xlabel("Country")
plt.ylabel("Number of Official Languages")
plt.title("Countries with Exactly Four Official Languages")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
