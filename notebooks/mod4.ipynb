# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sqlalchemy import create_engine
#       2
#       3 engine = create_engine(
#       4     "postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world"
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg://postgres:YOUR_PASSWORD@localhost:5432/world"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sqlalchemy import create_engine
#       2
# ----> 3 engine = create_engine(
#       4     "postgresql+psycopg://postgres:YOUR_PASSWORD@localhost:5432/world"
#       5 )
#
# File <string>:2, in create_engine(url, **kwargs)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world"
)

# %%
with engine.connect() as connection:
    print("Connected successfully!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg://postgres:A09a11S28!@localhost:5432/world"
)

# %%
with engine.connect() as connection:
    print("Connected successfully!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\Repos\my-databases-for-analytics\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg://postgres:A09a11S28!@localhost:5432/World"
)

# %%
with engine.connect() as connection:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
query = """
SELECT
    c.name AS country_name,
    COUNT(cl.language) AS official_language_count
FROM country AS c
JOIN countrylanguage AS cl
    ON c.code = cl.countrycode
WHERE cl.isofficial = 'T'
GROUP BY c.code, c.name
HAVING COUNT(cl.language) > 2
ORDER BY official_language_count DESC;
"""

# %%
df = pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_sql_query(query, engine)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
from sqlalchemy import create_engine
